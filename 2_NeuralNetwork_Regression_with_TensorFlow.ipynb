# %% [markdown]
# <a href="https://colab.research.google.com/github/ChavanSnehal322/Learning-TensorFlow/blob/main/2_NeuralNetwork_Regression_with_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

print( tf.__version__)
# Out:
# 2.19.0

# %%
# Regression
#  guessing some dimensions based on dependent or independent features of inputs/ parameters / numerical encodings
#  to be passed as input into a machine learning algorithms to generate the output

#  I/O shapes :
  # input will be a numerical encoding in form of tensor matrix
  #  output will be a single constraint for the problem to be predicted

# %% [markdown]
# #  Creating a data to view and fit in the regression model

# %%
import numpy as np
import matplotlib.pyplot as plt


#  Creating features ( independent variable)
X = np.array([-7.0, - 4., -1., 2., 5. , 8., 11., 14. ])

#  Creating labels ( dependent variable)
Y = np.array([3., 6., 9., 12., 15., 18., 21. , 24.  ])

#  Visuakizing created data
plt.scatter(X, Y)

# %%
#  Relationship of x and y ( independent and dependent variable)

Y == X + 10
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# #  Input & Output shapes for regression

# %%
#  Predicting house price

#  Inputs = no. of bedrooms, baths, cars ( 3)
#  Outputs = price of house ( 1)

house_param = tf.constant(["bedroom", "bath", "cars"])
house_price = tf.constant([939700])

house_param, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bath', b'cars'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
input_shape = X.shape
output_shape = Y.shape

input_shape, output_shape
# Out:
# ((8,), (8,))

# %%
X[0], Y[0]
# Out:
# (np.float64(-7.0), np.float64(3.0))

# %%
#  Converting nparrays to tensors ( default stype will be float32)

x = tf.constant(X, dtype= tf.float32)
y = tf.constant(Y, dtype= tf.float32)

x, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
input_shape = x[0].shape
output_shape = y[0].shape

input_shape, output_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %%
plt.scatter(x, y)

# %% [markdown]
# Steps for modelling with TensorFlow
#
# - Create a model = defining the input and output layers, hidden layers of Deep learning model
#
# - Compiling a model = define loss function (to tell how wrong the model is), optimizer (onforms model how to improve the patterns it is learning), and evaluation metric ( what features can be used to predict model performance)
#
# - Fitting of model = Allowing model to find patterns between x and y

# %%
#  finding sequential for the model defining

#  group linear stack of layers into a tf.keras.model by providing training and inference features on this model

# %%
#  importing sequential model
from tensorflow.keras.models import Sequential

#  set random seed

tf.random.set_seed(42)

#  Creating model using sequential API

model = tf.keras.Sequential( [

     tf.keras.layers.Dense(1)
] )

#  Compile the model ( using mean absolute error - MSE - compares the predicted and observed functions)
model.compile(
              loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics=["mae"])

#  Fit he model to let it find out patterns/ relationships between x and y

model.fit( tf.expand_dims(x, axis = -1), y, epochs = 5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step - loss: 16.9182 - mae: 16.9182
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 16.6369 - mae: 16.6369
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 16.3557 - mae: 16.3557
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 16.0744 - mae: 16.0744
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 15.7932 - mae: 15.7932

# %%
#  checking x and y

x, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
#  Checking and making prediction using our model


import numpy as np

pred_y = model.predict(np.array([[17.0]] ))
pred_y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# array([[-8.99697]], dtype=float32)

# %%
pred_y + 11
# Out:
# array([[2.0030298]], dtype=float32)

# %%
#  Improving the model:

# 1.  Adding the hidden layers, increase no. of neurons, change activation functions of each layers
# 2.  Change optimization function/ learning rate
# 3.  Provide more examples to model to learn and predict

# %%
# Improving model by increasing the epoch to 100

#  Creating model using sequential API

Imp_model = tf.keras.Sequential( [

     tf.keras.layers.Dense(1)

] )

#  Compile the model ( using mean absolute error - MSE - compares the predicted and observed functions)

Imp_model.compile(
              loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics=["mae"])

#  Fit he model to let it find out patterns/ relationships between x and y

Imp_model.fit( tf.expand_dims(x, axis = -1), y, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 16.9380 - mae: 16.9380
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 16.6568 - mae: 16.6568
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 16.3755 - mae: 16.3755
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 16.0943 - mae: 16.0943
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 15.8130 - mae: 15.8130
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 15.5318 - mae: 15.5318
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 15.2505 - mae: 15.2505
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 14.9693 - mae: 14.9693
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 14.7620 - mae: 14.7620
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 14.6295 - mae: 14.6295
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 14.4970 - mae: 14.4970
# Epoch 12/100
# ...

# %%
#  checking the data
x, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
#  Predicting the outputs


import numpy as np

# Convert your list to a 2D NumPy array
input_data = np.array([[17.0]])

# Run the prediction
prediction = Imp_model.predict(input_data)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# [[29.581192]]

# %%
#  Improving model by increasing hidden layers and neurons count

im_model = tf.keras.Sequential([

          tf.keras.layers.Dense(100, activation="relu"),
          tf.keras.layers.Dense(1)
])

im_model.compile( loss = "mae",
              optimizer= tf.keras.optimizers.SGD(),
               metrics= ["mae"] )

im_model.fit( tf.expand_dims(x, axis = -1), y, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 13.8109 - mae: 13.8109
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 13.2257 - mae: 13.2257
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 12.6440 - mae: 12.6440
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - loss: 12.0743 - mae: 12.0743
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 11.5097 - mae: 11.5097
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 10.9856 - mae: 10.9856
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 10.4506 - mae: 10.4506
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 9.8938 - mae: 9.8938
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 9.3176 - mae: 9.3176
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 8.7144 - mae: 8.7144
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 8.0795 - mae: 8.0795
# Epoch 12/100
# ...

# %%
x, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
import numpy as np

# Convert your list to a 2D NumPy array
input_data = np.array([[17.0]])

# Run the prediction
prediction = im_model.predict(input_data)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# [[31.256554]]

# %%
#  Previous model output is closest to the correct / predicted output
#  The model is overfitted, training data is learned very well by model

# %%
#  Improving model by increasing hidden layers  and neurons count by 50

im1_model = tf.keras.Sequential([

          tf.keras.layers.Dense(50, activation=None),
          tf.keras.layers.Dense(1)
])

# changin g the SGD model with Adam
#  improvimg learning rate by 10 ,  lr is important hyperparamter for a model

im1_model.compile( loss = "mae",
              optimizer= tf.keras.optimizers.Adam(learning_rate= 0.01),
               metrics= ["mae"] )

im1_model.fit( tf.expand_dims(x, axis = -1), y, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step - loss: 11.9097 - mae: 11.9097
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 11.1480 - mae: 11.1480
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 10.3740 - mae: 10.3740
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 9.5873 - mae: 9.5873
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 8.7873 - mae: 8.7873
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 7.9731 - mae: 7.9731
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.1428 - mae: 7.1428
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 6.9136 - mae: 6.9136
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 7.3578 - mae: 7.3578
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.7014 - mae: 7.7014
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.9083 - mae: 7.9083
# Epoch 12/100
# ...

# %%
x,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
import numpy as np

# Convert your list to a 2D NumPy array
input_data = np.array([[17.0]])

# Run the prediction
prediction = im1_model.predict(input_data)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# [[27.112423]]

# %% [markdown]
# #  Evaluating a model
#
# In practice workflow:
#
# Build a model -> fit it -> evaluate it -> tweak a model -> fit it -> evaluate it -> tweak model -> fit it -> evaluate it .........
#
# Vizualization is important in evaluation
#
# - Data we are working on , structure of it
# - Model - what does it look like
# - Training model - How does it perform while the learning process
# - Predictions of model - Gow does pred line up against ground truth

# %%
#  Creating bigger dataset

P = tf.range( -100, 100, 4)
P
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
# Make labels of dataset

Q = P + 10
Q
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
#  Visualizing the data

import matplotlib.pyplot as plt

plt.scatter(P, Q)

# %%
#  Three (3) sets of data in ML

#  Splitting the data into training and testing data

#  Training data = Model learns from the data, 70 - 80 % of original available data
#  Validation set = Model gets tuned on this data, 10 - 15% of available data
#  Testing data = MOdel is evaluated on this data to test the learnings, 10 - 20% of available data

# %%
#  Length of the data

len(P)
# Out:
# 50

# %%
#  Splitting data into train and test set

#  80 % data

#  model learns based on this data
x_train =  P[:40]
y_train = Q[:40]

#  20 % of data

#  for given x value predict the y value
x_test = P[40:]
y_test = Q[40:]

len( x_train), len(y_train), len(x_test), len(y_test)
# Out:
# (40, 40, 10, 10)

# %%
#  Visualizing the data

plt.figure(figsize=(10, 7))

#  plt train data in blue
plt.scatter(x_train, y_train, c = "b", label= "Train data")

#  plt test data in green
plt.scatter(x_test, y_test, c = "g", label = "Testing data")

#  show legend
plt.legend()

# %%
#  Building Neural network for the data

#  creating model
model = tf.keras.Sequential([

      tf.keras.layers.Dense(1)
])

#  compile model

model.compile( loss = tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.SGD(),
               metrics=["mae"]
               )

# #  Fitting the model
# model.fit(x_train, y_train, epoch= 100)

# %%
#  visualizing the data

model.summary()
# model.build()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
P[0], Q[0]
# Out:
# (<tf.Tensor: shape=(), dtype=int32, numpy=-100>,
#  <tf.Tensor: shape=(), dtype=int32, numpy=-90>)

# %%
#  Creating a model that builds automatically by defining input shape arguments

tf.random.set_seed(42)

#  create a model
model = tf.keras.Sequential([

          tf.keras.layers.Dense(1, input_shape = [1])

])

model.compile(loss = tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics = ["mae"]
              )
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# total param = total no. of parameters in the model
# trainable param = parameters(patterns) the model can update after its training
# non trainable params = parameters aren't updated during training( typically when the already learned
# param/ patterns are brought from other model during transfer learning)

# %%
#  model.fit(x_train, y_train, epochs= 100, verbose = 1)

# %%
#  Bias and weights

# %%
#  Creating a model that builds automatically by defining input shape arguments

tf.random.set_seed(42)

#  create a model
model = tf.keras.Sequential([

          tf.keras.layers.Dense(1, input_shape = [1])

])

model.compile(loss = tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics = ["mae"]
              )

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Running the model fit multiple times will increase epoch count

model.fit(x_train, y_train, epochs= 100, verbose = 0)

# Expand dimensions of x_train to make it (batch_size, n_features)
# model.fit(tf.expand_dims(x_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4 (20.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
# Visualizing the model using plt function

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model = model, show_shapes = True)

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([

                             tf.keras.layers.Dense( 10, input_shape = [1], name = "input_layer"),
                             tf.keras.layers.Dense(1, name = "output_lauers"
                             )
], name = "model_1")

model.compile( loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ["mae" ]
               )
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "model_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (Dense)             │ (None, 10)             │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_lauers (Dense)           │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train, y_train, epochs = 100, verbose = 0)

# %%
model.summary()
# Out:
# Model: "model_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (Dense)             │ (None, 10)             │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_lauers (Dense)           │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33 (136.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
plot_model(model=model, show_shapes=True)

# %%
#  Visualizing model predictions
#  plot them against ground truth tables
#  ( y_test or y_true vs y_pred)
#  on test dataset

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x784037ff1bc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# array([[33.8012  ],
#        [35.951317],
#        [38.10143 ],
#        [40.251537],
#        [42.40165 ],
#        [44.55176 ],
#        [46.701874],
#        [48.851982],
#        [51.002098],
# ...

# %%
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
#  Creating a plotting function to visualize predictions

def plot_preds( train_data = x_train,
               train_labels = y_train,
               test_data = x_test,
               test_labels = y_test,
               predictions = y_pred):

  plt.figure(figsize=( 10, 7))

  #  training data = blue
  plt.scatter(train_data, train_labels, c = "b", label = "Training data")

  #  testing data = green
  plt.scatter( test_data, test_labels, c = "g", label = "Testing data")

  #  predictions = red
  plt.scatter(test_data, predictions, c = "r", label = "Predictions")

  plt.legend();

# %%
plot_preds()

# %%
plot_preds( train_data= x_train,
            train_labels= y_train,
            test_data= x_test,
            test_labels= y_test,
            predictions = y_pred
            )

# %%
#  Evaluation predictioins with regression evaluation metrics

# MAE (Mean Absolute Error ) = On average, how wrong is each of the  predictions made by model
# MSE ( Mean Square Error ) = Square the average errors

# %%
#  Evaluating the model on test data

model.evaluate(x_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 44.5233 - mae: 44.5233
# [44.52329635620117, 44.52329635620117]

# %%
#  Calculating mean absolute error

# mae = tf.metrics.mean_absolute_error(
mae = tf.keras.losses.MAE(
                                      y_true = y_test,
                                      y_pred = tf.constant(y_pred)
                                    )

mae
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([36.1988  , 38.048683, 39.89857 , 41.748463, 43.59835 , 45.44824 ,
#        47.298126, 49.148018, 50.997902, 52.847794], dtype=float32)>

# %%
tf.constant(y_pred)
# Out:
# <tf.Tensor: shape=(10, 1), dtype=float32, numpy=
# array([[33.8012  ],
#        [35.951317],
#        [38.10143 ],
#        [40.251537],
#        [42.40165 ],
#        [44.55176 ],
#        [46.701874],
#        [48.851982],
#        [51.002098],
#        [53.152206]], dtype=float32)>

# %%
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
tf.squeeze(y_pred)
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([33.8012  , 35.951317, 38.10143 , 40.251537, 42.40165 , 44.55176 ,
#        46.701874, 48.851982, 51.002098, 53.152206], dtype=float32)>

# %%
mae = tf.metrics.mae(
                      y_true = y_test,
                      y_pred = tf.squeeze(y_pred)
                      )

mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=44.52329635620117>

# %%
#  Mean Square Error
